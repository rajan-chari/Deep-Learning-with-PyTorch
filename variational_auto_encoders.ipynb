# %% [markdown]
# # 0. Setup

# %% [markdown]
# ## 0.1 Imports

# %%
import torch
import torchvision
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
from torchvision import transforms
from torchvision.datasets import MNIST
from torch.autograd import Variable
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# ## 0.2 Helpers

# %%
def set_default(figsize=(10, 10), dpi=100):
    plt.style.use(['dark_background', 'bmh'])
    plt.rc('axes', facecolor='k')
    plt.rc('figure', facecolor='k')
    plt.rc('figure', figsize=figsize, dpi=dpi)

import matplotlib.style
import matplotlib as mpl
# mpl.style.use('classic')
mpl.rcParams['image.cmap'] = 'viridis'


def display_images(in_, out, label, n=1, count=False):
    title_set = False
    for N in range(n):
      if in_ is not None:
        in_pic = in_.data.cpu().view(-1, 28, 28)
        plt.figure(figsize=(18, 4))
        if not title_set:
          plt.suptitle(label, color='w', fontsize=20)
          title_set = True
        for i in range(4):
            plt.subplot(1,4,i+1)
            plt.imshow(in_pic[i+4*N])
            plt.axis('off')
      if out is not None:
        out_pic = out.data.cpu().view(-1, 28, 28)
        plt.figure(figsize=(18, 6))
        if not title_set:
          plt.suptitle(label, color='w', fontsize=20)
          title_set = True
        for i in range(4):
            plt.subplot(1,4,i+1)
            plt.imshow(out_pic[i+4*N])
            plt.axis('off')
            if count: plt.title(str(4 * N + i), color='w')

def plot_samples_grid(ds_loader, n_rows=8, n_cols=8, fig_size=8, img_dim=28, title=None):
  
  f, axarr = plt.subplots(n_rows, n_cols, figsize=(fig_size, fig_size))

  images, labels = next(iter(ds_loader))

  for i, ax in enumerate(axarr.flat):
      ax.imshow(images[i].view(img_dim, img_dim))
      ax.axis('off')
      
  plt.suptitle(title)
  plt.show()

# %% [markdown]
# ## 0.3 Globals

# %%
# set random seeds
torch.manual_seed(1)
torch.cuda.manual_seed(1)

# setup device cuda vs. cpu
cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if cuda else "cpu")

# %% [markdown]
# # 1. Prepare Dataset

# %% [markdown]
# ## 1.1. Load MNIST

# %%
# set batch size
batch_size = 256

# %%
# transformation to apply to each data point (image)
transformer = lambda x: transforms.ToTensor()(x)

# define the train and test datasets
ds_train = MNIST("./data", train=True, transform=transformer, download=True)
ds_test = MNIST("./data", train=False, transform=transformer)

# data loaders to load data in batches from the datasets
train_loader = DataLoader(dataset=ds_train, batch_size=batch_size, shuffle=True, num_workers=1, pin_memory=cuda)
test_loader = DataLoader(dataset=ds_test, batch_size=batch_size, shuffle=True, num_workers=1, pin_memory=cuda)

# %% [markdown]
# ##1.2 Plot Random Samples

# %%
plot_samples_grid(train_loader, title='Original Images (Before Binarization)')

# %% [markdown]
# ##1.3 Transform to Binarized MNIST

# %%
def binarizer(x):
  intensities = transforms.ToTensor()(x)
  t = torch.Tensor([0.5])
  out = (intensities >= t).float() * 1
  return out

# define the train and test datasets
bin_ds_train = MNIST("./bin_data", train=True, transform=binarizer, download=True)
bin_ds_test = MNIST("./bin_data", train=False, transform=binarizer)

# data loaders to load data in batches from the datasets
bin_train_loader = DataLoader(dataset=bin_ds_train, batch_size=batch_size, shuffle=True, num_workers=1, pin_memory=cuda)
bin_test_loader = DataLoader(dataset=bin_ds_test, batch_size=batch_size, shuffle=True, num_workers=1, pin_memory=cuda)
# Out:
# 2.4%
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./bin_data/MNIST/raw/train-images-idx3-ubyte.gz
# 100.0%
# Extracting ./bin_data/MNIST/raw/train-images-idx3-ubyte.gz to ./bin_data/MNIST/raw
# 102.8%
# 0.4%
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./bin_data/MNIST/raw/train-labels-idx1-ubyte.gz
# Extracting ./bin_data/MNIST/raw/train-labels-idx1-ubyte.gz to ./bin_data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./bin_data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100.0%
# 112.7%
# Extracting ./bin_data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./bin_data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./bin_data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# Extracting ./bin_data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./bin_data/MNIST/raw

# %% [markdown]
# ##1.4 Plot Binarized MNIST Samples

# %%
plot_samples_grid(bin_train_loader, title='Binarized Images')

# %% [markdown]
# # 2. VAE

# %% [markdown]
# ## 2.1. Setting up the model

# %% [markdown]
# ### 2.1.1 Implement a VAE Module

# %%
# hyper params
latent_size = 20

# %%
class VAE(nn.Module):
    def __init__(self):
        super().__init__()

        self.encoder = nn.Sequential(
            nn.Linear(784, latent_size ** 2),
            nn.ReLU(),
            nn.Linear(latent_size ** 2, latent_size * 2)
        )

        self.decoder = nn.Sequential(
            nn.Linear(latent_size, latent_size ** 2),
            nn.ReLU(),
            nn.Linear(latent_size ** 2, 784),
            nn.Sigmoid(),
        )

    def reparameterise(self, mu, logvar):
        if self.training:
            std = logvar.mul(0.5).exp_()
            eps = std.data.new(std.size()).normal_()
            return eps.mul(std).add_(mu)
        else:
            return mu

    def encode(self, x):
      mu_logvar = self.encoder(x.view(-1, 784)).view(-1, 2, latent_size)
      mu = mu_logvar[:, 0, :]
      logvar = mu_logvar[:, 1, :]
      return mu, logvar

    def decode(self, z):
      return self.decoder(z)

    def forward(self, x):
        mu, logvar = self.encode(x)
        z = self.reparameterise(mu, logvar)
        x_hat = self.decode(z)
        return x_hat, mu, logvar

    def sample(self, n_samples):
      z = torch.randn((n_samples, latent_size)).to(device)
      return self.decode(z)

model = VAE().to(device)

# %%
# Setting the optimiser
learning_rate = 1e-3

optimizer = torch.optim.Adam(
    model.parameters(),
    lr=learning_rate,
)

# %%
# Reconstruction + KL divergence losses summed over all elements and batch
def loss_function(x_hat, x, mu, logvar):
    
    # reconstruction loss (pushing the points apart)
    BCE = nn.functional.binary_cross_entropy(
        x_hat, x.view(-1, 784), reduction='sum'
    )

    # KL divergence loss (the relative entropy between two distributions a multivariate gaussian and a normal)
    # (enforce a radius of 1 in each direction + pushing the means towards zero)
    KLD = 0.5 * torch.sum(logvar.exp() - logvar - 1 + mu.pow(2))

    return BCE + KLD # we can use a beta parameter here (BCE + beta * KLD)

# %% [markdown]
# ### 2.1.2. Generate samples from the untrained model

# %%
# Generating 64 samples from the untrained model
samples = model.sample(64)
display_images(None, samples, 'Generated Samples - Untrained Model', 64 // 4, count=True)

# %% [markdown]
# ### 2.1.3. ELBO of samples from training set using the untrained model

# %%
# Compute the ELBO of 64 samples from the training set using the untrained model
with torch.no_grad():
  model.eval()
  # load a batch (it will be of 256 samples)
  images, _ = next(iter(bin_train_loader))
  # we only want 64 samples
  only_64 = images[0:64, :, :, :]
  # send them to the appropriate device
  only_64 = only_64.to(device)
  # forward
  x_hat, mu, logvar = model(only_64)
  # TODO: there is a miss-match in the dims but the size is the same
  elbo_64_untrained = loss_function(x_hat, only_64, mu, logvar).item()

print(f'ELBO of 64 samples using the untrained model: {elbo_64_untrained:.4f}')
# Out:
# ELBO of 64 samples using the untrained model: 34883.4062

# %% [markdown]
# ## 2.2. Setting up the training

# %% [markdown]
# ### 2.2.1. Implement train and test functions

# %%
# performs one epoch of training and returns the training loss for this epoch
def train():
  model.train()
  train_loss = 0
  for x, _ in bin_train_loader:
    x = x.to(device)
    # ===================forward=====================
    x_hat, mu, logvar = model(x)
    loss = loss_function(x_hat, x, mu, logvar)
    train_loss += loss.item()
    # ===================backward====================
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
  return train_loss

# evaluates the model on the test set
def test(epoch):
  means, logvars, labels, images = list(), list(), list(), list()
  test_loss = 0
  with torch.no_grad():
    model.eval()
    for x, y in bin_test_loader:
      x = x.to(device)
      # forward
      x_hat, mu, logvar = model(x)
      test_loss += loss_function(x_hat, x, mu, logvar).item()
      # log
      means.append(mu.detach())
      logvars.append(logvar.detach())
      labels.append(y.detach())
      images.append(x.detach())
  display_images(None, x_hat, f'Epoch {epoch} - Reconstructed Images', 1)
  return test_loss, means, logvars, labels, images

# %% [markdown]
# ### 2.2.2. Train the model and Evaluate on the testset

# %%
# Training the model
epochs = 50
codes = dict(μ=list(), logσ2=list(), y=list(), x=list())
for epoch in range(1, epochs+1):
    
    # train for one epoch
    train_loss = train()

    # print the train loss for the epoch
    print(f'====> Epoch: {epoch} Average train loss: {train_loss / len(bin_train_loader.dataset):.4f}')
    
    # evaluate this epoch over the test set
    test_loss, means, logvars, labels, images = test(epoch)

    # log for analysis
    codes['μ'].append(torch.cat(means))
    codes['logσ2'].append(torch.cat(logvars))
    codes['y'].append(torch.cat(labels))
    codes['x'].append(torch.cat(images))

    # print the test loss for the epoch
    print(f'====> Epoch: {epoch} Average test loss: {test_loss / len(bin_test_loader.dataset):.4f}')
# Out:
# ====> Epoch: 1 Average train loss: 184.7091
# ====> Epoch: 1 Average test loss: 126.8547
# ====> Epoch: 2 Average train loss: 122.1692
# ====> Epoch: 2 Average test loss: 102.7833
# ====> Epoch: 3 Average train loss: 108.0476
# ====> Epoch: 3 Average test loss: 94.2641
# ====> Epoch: 4 Average train loss: 101.7534
# ====> Epoch: 4 Average test loss: 90.1103
# ====> Epoch: 5 Average train loss: 98.2623
# ====> Epoch: 5 Average test loss: 87.6297
# ====> Epoch: 6 Average train loss: 95.8981
# ====> Epoch: 6 Average test loss: 85.5574
# ====> Epoch: 7 Average train loss: 94.1270
# ====> Epoch: 7 Average test loss: 84.2028
# ====> Epoch: 8 Average train loss: 92.7625
# ====> Epoch: 8 Average test loss: 82.6067
# ====> Epoch: 9 Average train loss: 91.6372
# ====> Epoch: 9 Average test loss: 81.1924
# ====> Epoch: 10 Average train loss: 90.6192
# ====> Epoch: 10 Average test loss: 80.3969
# ====> Epoch: 11 Average train loss: 89.9329
# ====> Epoch: 11 Average test loss: 80.2543
# ====> Epoch: 12 Average train loss: 89.2310
# ====> Epoch: 12 Average test loss: 79.6892
# ====> Epoch: 13 Average train loss: 88.6552
# ====> Epoch: 13 Average test loss: 79.5693
# ====> Epoch: 14 Average train loss: 88.0988
# ====> Epoch: 14 Average test loss: 78.4170
# ====> Epoch: 15 Average train loss: 87.6704
# ====> Epoch: 15 Average test loss: 78.6808
# ====> Epoch: 16 Average train loss: 87.1907
# ====> Epoch: 16 Average test loss: 78.6646
# ====> Epoch: 17 Average train loss: 86.8922
# ====> Epoch: 17 Average test loss: 78.2404
# ====> Epoch: 18 Average train loss: 86.5563
# ====> Epoch: 18 Average test loss: 77.8036
# ====> Epoch: 19 Average train loss: 86.2326
# ====> Epoch: 19 Average test loss: 77.4090
# ====> Epoch: 20 Average train loss: 85.9316
# ====> Epoch: 20 Average test loss: 77.4879
# ====> Epoch: 21 Average train loss: 85.7364
# ====> Epoch: 21 Average test loss: 77.1653
# <ipython-input-3-49abbfef6786>:28: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(18, 6))
# ====> Epoch: 22 Average train loss: 85.4088
# ====> Epoch: 22 Average test loss: 76.7017
# ====> Epoch: 23 Average train loss: 85.1807
# ====> Epoch: 23 Average test loss: 76.8016
# ====> Epoch: 24 Average train loss: 85.0500
# ====> Epoch: 24 Average test loss: 76.9430
# ====> Epoch: 25 Average train loss: 84.7491
# ====> Epoch: 25 Average test loss: 76.6897
# ====> Epoch: 26 Average train loss: 84.5419
# ====> Epoch: 26 Average test loss: 76.3658
# ====> Epoch: 27 Average train loss: 84.3989
# ====> Epoch: 27 Average test loss: 76.3187
# ====> Epoch: 28 Average train loss: 84.2299
# ====> Epoch: 28 Average test loss: 76.0056
# ====> Epoch: 29 Average train loss: 84.0665
# ====> Epoch: 29 Average test loss: 75.6007
# ====> Epoch: 30 Average train loss: 83.8698
# ====> Epoch: 30 Average test loss: 75.8228
# ====> Epoch: 31 Average train loss: 83.7264
# ====> Epoch: 31 Average test loss: 75.9955
# ====> Epoch: 32 Average train loss: 83.5997
# ====> Epoch: 32 Average test loss: 75.7868
# ====> Epoch: 33 Average train loss: 83.4785
# ====> Epoch: 33 Average test loss: 75.6564
# ====> Epoch: 34 Average train loss: 83.2964
# ====> Epoch: 34 Average test loss: 75.3554
# ====> Epoch: 35 Average train loss: 83.1972
# ====> Epoch: 35 Average test loss: 75.2211
# ====> Epoch: 36 Average train loss: 83.0644
# ====> Epoch: 36 Average test loss: 75.5034
# ====> Epoch: 37 Average train loss: 82.9273
# ====> Epoch: 37 Average test loss: 75.8209
# ====> Epoch: 38 Average train loss: 82.8722
# ====> Epoch: 38 Average test loss: 74.9092
# ====> Epoch: 39 Average train loss: 82.7350
# ====> Epoch: 39 Average test loss: 74.9520
# ====> Epoch: 40 Average train loss: 82.6207
# ====> Epoch: 40 Average test loss: 74.6153
# ====> Epoch: 41 Average train loss: 82.5419
# ====> Epoch: 41 Average test loss: 75.7095
# ====> Epoch: 42 Average train loss: 82.4162
# ====> Epoch: 42 Average test loss: 75.0039
# ====> Epoch: 43 Average train loss: 82.3027
# ====> Epoch: 43 Average test loss: 75.3143
# ====> Epoch: 44 Average train loss: 82.2410
# ====> Epoch: 44 Average test loss: 74.2217
# ====> Epoch: 45 Average train loss: 82.1799
# ====> Epoch: 45 Average test loss: 75.2529
# ====> Epoch: 46 Average train loss: 82.1137
# ====> Epoch: 46 Average test loss: 74.7434
# ====> Epoch: 47 Average train loss: 82.0149
# ====> Epoch: 47 Average test loss: 74.7723
# ====> Epoch: 48 Average train loss: 81.9229
# ====> Epoch: 48 Average test loss: 73.8921
# ====> Epoch: 49 Average train loss: 81.8172
# ====> Epoch: 49 Average test loss: 74.4051
# ====> Epoch: 50 Average train loss: 81.7543
# ====> Epoch: 50 Average test loss: 75.2650

# %%
# save the state dict of the model
torch.save(model.state_dict(), 'vae-model.pt')

# %%
# loading a saved module
model = VAE().to(device)
model.load_state_dict(torch.load('vae-model.pt'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ### 2.2.3. Generating samples from the trained model

# %%
# Generate 64 samples from the trained model and plot them.
samples = model.sample(64)
display_images(None, samples, 'Generated Samples - Trained Model', 64 // 4, count=True)

# %% [markdown]
# # 3. Model Analysis

# %% [markdown]
# ## 3.1. Interpolation - Start and End

# %%
# Choose starting and ending point for the interpolation -> shows original and reconstructed
A, B = 12, 26
sample = model.decoder(torch.stack((codes['μ'][epoch-1][A].data, codes['μ'][epoch-1][B].data), 0))
display_images(None, torch.stack(((
    codes['x'][epoch-1][A].data.view(-1),
    codes['x'][epoch-1][B].data.view(-1),
    sample.data[0],
    sample.data[1]
))), 'Interpolation Start and End')

# %% [markdown]
# ## 3.2. Interpolation in N

# %%
# Perform a linear interpolation between 2 inputs A and B in the latent space and send it through the decoder
# by walking in the latent space we get to reconstruct things that look legit in the input space
N = 16
code = torch.Tensor(N, 20).to(device)
sample = torch.Tensor(N, 28, 28).to(device)
for i in range(N):
    code[i] = i / (N - 1) * codes['μ'][epoch-1][B].data + (1 - i / (N - 1) ) * codes['μ'][epoch-1][A].data
sample = model.decoder(code)
display_images(None, sample, 'Interpolation in N steps', N // 4, count=True)

# %% [markdown]
# ## 3.3. Plot latent space

# %% [markdown]
# Showing a representation of the embeddings (of the means) of the test set where we perform a dimensionality reduction which shows how the encoder clusters all the means in different regions in the latent space.

# %%
import numpy as np
from sklearn.manifold import TSNE

# %%
X, Y, E = list(), list(), list()  # input, classes, embeddings
N = 1000  # samples per epoch
epochs = (0, 24, 49)
for epoch in epochs:
    X.append(codes['μ'][epoch][:N])
    E.append(TSNE(n_components=2).fit_transform(X[-1]))
    Y.append(codes['y'][epoch][:N])
# Out:
# /home/ranaras/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/ranaras/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /home/ranaras/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/ranaras/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /home/ranaras/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/ranaras/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
set_default(figsize=(20, 6))

# %%
f, a = plt.subplots(ncols=3)
for i, e in enumerate(epochs):
    s = a[i].scatter(E[i][:,0], E[i][:,1], c=Y[i], cmap='tab10')
    a[i].grid(False)
    a[i].set_title(f'Epoch {e}')
    a[i].axis('equal')
f.colorbar(s, ax=a[:], ticks=np.arange(10), boundaries=np.arange(11) - .5)
# Out:
# <ipython-input-28-ac99407ef069>:7: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   f.colorbar(s, ax=a[:], ticks=np.arange(10), boundaries=np.arange(11) - .5)

# %% [markdown]
# # 4. Semi-Supervised VAE

# %% [markdown]
# ## 4.1. Prepare dataset

# %% [markdown]
# ### 4.1.1. Creating a subset of the dataset

# %%
# extract 100 labeled datapoints (10 from each class)
data_list, targets_list = [], []

# take 10 of each class
for class_ in range(10):
  idx = bin_ds_train.targets == class_
  data_list.append(bin_ds_train.data[idx][0:10, :, :])
  targets_list.append(bin_ds_train.targets[idx][0:10])

# convert the lists to tensors
mini_ds_data = torch.cat(data_list, 0)
mini_ds_targets = torch.cat(targets_list, 0)

# make sure the type is correct
mini_ds_data = mini_ds_data.to(dtype=torch.float32)
mini_ds_targets = mini_ds_targets.to(dtype=torch.long)

# create a dataset and a loader
mini_ds = TensorDataset(mini_ds_data, mini_ds_targets)
mini_dl = DataLoader(mini_ds, batch_size=100, drop_last=False, shuffle=False, num_workers=1, pin_memory=cuda)

# plot all the dataset
plot_samples_grid(mini_dl, n_rows=10, n_cols=10, title='Mini MNIST')

# %% [markdown]
# ### 4.1.2. Process mini dataset to convert images to latent vectors

# %%
with torch.no_grad():
  model.eval()
  for x, _ in mini_dl:
    x = x.to(device)
    # encode
    mu, logvar = model.encode(x)
    # reparameterize (there will be 1 batch only)
    z = model.reparameterise(mu, logvar)

# make sure the type is correct
mini_ds_latent_vectors = z.to(dtype=torch.float32)

# %%
# prepare the new mini dataset for training classifiers
latent_mini_ds = TensorDataset(mini_ds_latent_vectors, mini_ds_targets)
latent_mini_dl = DataLoader(latent_mini_ds, batch_size=4, drop_last=False, shuffle=True, num_workers=1, pin_memory=cuda)

# %% [markdown]
# ## 4.2. Classifiers

# %%
# to collect info about the performance of the various classifiers
clf_stats = {}

# %% [markdown]
# ### 4.2.1. Linear Classifier

# %%
# a simple linear model
class LinearClassifier(nn.Module):

  def __init__(self):
      super(LinearClassifier, self).__init__()
      
      self.layer_1 = nn.Linear(in_features=latent_size, out_features=10, bias=True)

  def forward(self, x):
    x = x.view(-1, latent_size)
    logits = self.layer_1(x)
    return F.log_softmax(logits, dim=1)

linearClassifier = LinearClassifier()
print(linearClassifier)
# Out:
# LinearClassifier(
#   (layer_1): Linear(in_features=20, out_features=10, bias=True)
# )

# %%
criterion = nn.NLLLoss()
optimizer = torch.optim.Adam(linearClassifier.parameters(), lr=0.001)

# %%
epochs = 100
train_loss_vals, test_loss_vals, test_accuracies = [], [], []
for epoch in range(1, epochs+1): 
  # train on the mini dataset (the latent version)
  linearClassifier.train()
  train_loss = 0
  for x, y in latent_mini_dl:
    x = x.to(device) # the latent vector
    y = y.to(device) # the target label
    # forward
    y_hat = linearClassifier(x)
    loss = criterion(y_hat, y)
    train_loss += loss.item()
    # backward
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
  
  train_loss /= len(latent_mini_dl.dataset)
  train_loss_vals.append(train_loss)
  
  # evaluate over the whole test set
  with torch.no_grad():
    linearClassifier.eval()
    test_loss = 0
    correct = 0
    for x, y in bin_test_loader:
        x = x.to(device) # the image
        y = y.to(device) # the target label

        # we need to encode to latent vectors
        model.eval()
        mu, logvar = model.encode(x)
        z = model.reparameterise(mu, logvar)

        # forward
        y_hat = linearClassifier(z)
        test_loss += F.nll_loss(y_hat, y, reduction='sum').item()  # sum up batch loss
        pred = y_hat.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
        correct += pred.eq(y.view_as(pred)).sum().item()

  accuracy = 100. * correct / len(bin_test_loader.dataset)
  test_loss /= len(bin_test_loader.dataset)
  test_loss_vals.append(test_loss)
  test_accuracies.append(accuracy)

  if epoch % 10 == 0:
    print(f'===== Epoch {epoch} =====')
    print(f'Average train loss: {train_loss:.4f}')
    print(f'Average test loss: {test_loss:.4f}, Accuracy: {accuracy:.0f}%')

# save avg accuracy to clf_stats
clf_stats['m1_linear_model'] = max(test_accuracies)
# Out:
# ===== Epoch 10 =====
# Average train loss: 10.5145
# Average test loss: 2.0148, Accuracy: 34%
# ===== Epoch 20 =====
# Average train loss: 2.0301
# Average test loss: 1.9234, Accuracy: 46%
# ===== Epoch 30 =====
# Average train loss: 0.4481
# Average test loss: 1.8915, Accuracy: 49%
# ===== Epoch 40 =====
# Average train loss: 0.0014
# Average test loss: 1.8787, Accuracy: 50%
# ===== Epoch 50 =====
# Average train loss: 0.0003
# Average test loss: 1.8776, Accuracy: 50%
# ===== Epoch 60 =====
# Average train loss: 0.0002
# Average test loss: 1.8771, Accuracy: 50%
# ===== Epoch 70 =====
# Average train loss: 0.0002
# Average test loss: 1.8767, Accuracy: 50%
# ===== Epoch 80 =====
# Average train loss: 0.0001
# Average test loss: 1.8764, Accuracy: 50%
# ===== Epoch 90 =====
# Average train loss: 0.0001
# Average test loss: 1.8761, Accuracy: 50%
# ===== Epoch 100 =====
# Average train loss: 0.0001
# Average test loss: 1.8758, Accuracy: 50%

# %%
set_default(figsize=(6, 4), dpi=100)
plt.title('Training Loss')
plt.plot(range(1, epochs+1), train_loss_vals)

# %%
set_default(figsize=(6, 4), dpi=100)
plt.title('Test Loss')
plt.plot(range(1, epochs+1), test_loss_vals)

# %%
set_default(figsize=(6, 4), dpi=100)
plt.title('Test Accuracy')
plt.plot(range(1, epochs+1), test_accuracies)

# %% [markdown]
# ## 4.3. Baseline

# %%
class Net(nn.Module):
  def __init__(self):
    super(Net, self).__init__()
    self.l1 = nn.Linear(784, 32)
    self.l2 = nn.Linear(32, 16)
    self.l3 = nn.Linear(16, 10)

  def forward(self, x):
    x = x.view(x.shape[0], -1)
    x = F.relu(self.l1(x))
    x = F.relu(self.l2(x))
    x = self.l3(x)
    return F.log_softmax(x, dim=1)

baseline_model = Net().to(device)
print(baseline_model)
# Out:
# Net(
#   (l1): Linear(in_features=784, out_features=32, bias=True)
#   (l2): Linear(in_features=32, out_features=16, bias=True)
#   (l3): Linear(in_features=16, out_features=10, bias=True)
# )

# %%
criterion = nn.NLLLoss() # the negative log-likelihood loss.
optimizer = torch.optim.SGD(baseline_model.parameters(), lr=0.001, momentum=0.5)

# %%
# use a different loader to adjust loading settings
bl_mini_dl = DataLoader(mini_ds, batch_size=5, drop_last=False, shuffle=True, num_workers=1, pin_memory=cuda)

# %%
epochs = 100
train_loss_vals, test_loss_vals, test_accuracies = [], [], []
for epoch in range(1, epochs+1):
  # train using only the 100 labeled data points
  baseline_model.train()
  train_loss = 0
  for x, y in bl_mini_dl:
    x = x.to(device)
    y = y.to(device)
    # forward
    y_hat = baseline_model(x)
    loss = criterion(y_hat, y)
    train_loss += loss.item()
    # backward
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
  
  train_loss /= len(bl_mini_dl.dataset)
  train_loss_vals.append(train_loss)

  # evaluate over the whole test set
  with torch.no_grad():
    baseline_model.eval()
    test_loss = 0
    correct = 0
    for x, y in bin_test_loader:
      x = x.to(device)
      y = y.to(device)

      # forward
      y_hat = baseline_model(x)
      test_loss += F.nll_loss(y_hat, y, reduction='sum').item()  # sum up batch loss
      pred = y_hat.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
      correct += pred.eq(y.view_as(pred)).sum().item()
  
  accuracy = 100. * correct / len(bin_test_loader.dataset)
  test_loss /= len(bin_test_loader.dataset)
  test_loss_vals.append(test_loss)
  test_accuracies.append(accuracy)

  if epoch % 10 == 0:
    print(f'===== Epoch {epoch} =====')
    print(f'Average train loss: {train_loss:.4f}')
    print(f'Average test loss: {test_loss:.4f}, Accuracy: {accuracy:.0f}%')

# save avg accuracy to clf_stats
clf_stats['baseline_model'] = max(test_accuracies)
# Out:
# ===== Epoch 10 =====
# Average train loss: 0.0627
# Average test loss: 2.2775, Accuracy: 19%
# ===== Epoch 20 =====
# Average train loss: 0.0081
# Average test loss: 2.2699, Accuracy: 24%
# ===== Epoch 30 =====
# Average train loss: 0.0025
# Average test loss: 2.2655, Accuracy: 25%
# ===== Epoch 40 =====
# Average train loss: 0.0011
# Average test loss: 2.2630, Accuracy: 26%
# ===== Epoch 50 =====
# Average train loss: 0.0007
# Average test loss: 2.2613, Accuracy: 26%
# ===== Epoch 60 =====
# Average train loss: 0.0005
# Average test loss: 2.2601, Accuracy: 26%
# ===== Epoch 70 =====
# Average train loss: 0.0004
# Average test loss: 2.2592, Accuracy: 27%
# ===== Epoch 80 =====
# Average train loss: 0.0003
# Average test loss: 2.2584, Accuracy: 27%
# ===== Epoch 90 =====
# Average train loss: 0.0003
# Average test loss: 2.2577, Accuracy: 27%
# ===== Epoch 100 =====
# Average train loss: 0.0002
# Average test loss: 2.2571, Accuracy: 27%

# %%
set_default(figsize=(6, 4), dpi=100)
plt.title('Training Loss')
plt.plot(range(1, epochs+1), train_loss_vals)

# %%
set_default(figsize=(6, 4), dpi=100)
plt.title('Test Loss')
plt.plot(range(1, epochs+1), test_loss_vals)

# %%
set_default(figsize=(6, 4), dpi=100)
plt.title('Test Accuracy')
plt.plot(range(1, epochs+1), test_accuracies)

# %% [markdown]
# ## 4.4. Overall comparison

# %%
clf_stats
# Out:
# {'m1_linear_model': 50.0, 'baseline_model': 27.44}

# %%
names = list(clf_stats.keys())
values = list(clf_stats.values())

plt.style.use(['fivethirtyeight'])
plt.rc('axes', facecolor='w')
plt.rc('figure', facecolor='silver')
plt.rc('figure', figsize=(10, 6), dpi=100)

plt.title('Accuracy Comparison')
bg = plt.bar(['NN Linear Model', 'Baseline NN'], values, color=(0.2, 0.4, 0.6, 0.6))
bg[1].set_color('crimson')
